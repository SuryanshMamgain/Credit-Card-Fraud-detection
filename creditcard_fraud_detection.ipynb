# %%
import numpy as np
import pandas as pd

# %%
creditinfo=pd.read_csv("creditcard.csv")

# %%
creditcard=pd.DataFrame(creditinfo)
creditcard
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
creditcard["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
#checking missing values
creditcard.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
corrmatrix=creditcard.corr()
fig,ax=plt.subplots(figsize=(20,15))
ax=sns.heatmap(corrmatrix,
              annot=True,
              linewidths=0.5,
               fmt='.2f',
              cmap='YlGnBu')

# %%
# Boxplot to view outliers
plt.figure(figsize=(20,10), facecolor='w')
sns.boxplot(data=creditcard)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.scatter(creditcard.V1[creditcard["Class"]==1],creditcard.V13[creditcard["Class"]==1],c='salmon')
#plt.scatter(creditcard.V1[creditcard["Class"]==0],creditcard.V13[creditcard["Class"]==0],c='lightblue')

# %%
creditcard["Class"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Class'>

# %%
# %matplotlib inline
import seaborn as sns

# %%
frauddata=creditcard[creditcard['Class']==1]
truedata=creditcard[creditcard['Class']==0]

# %%
plt.figure(figsize=(20,10))
ax=sns.distplot(frauddata['Time'],label='Fraud',hist=False)
ax=sns.distplot(truedata['Time'],label='True',hist=False)
ax.set(xlabel='Seconds elapsed between the transction and the first transction')
plt.show()
# Out:
# /var/folders/gb/wfpxw53147l1nt875_lc9vbh0000gn/T/ipykernel_92929/1335366071.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(frauddata['Time'],label='Fraud',hist=False)
# /var/folders/gb/wfpxw53147l1nt875_lc9vbh0000gn/T/ipykernel_92929/1335366071.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# we can see that there is no dependency of time column

# %%
creditcard.drop('Time',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 creditcard.drop('Time',axis=1,inplace=True)
#
# File ~/Desktop/ml-course/heart-disease-project/env/lib/python3.10/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
# ...

# %%
creditcard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 30 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   V1      284807 non-null  float64
#  1   V2      284807 non-null  float64
#  2   V3      284807 non-null  float64
#  3   V4      284807 non-null  float64
#  4   V5      284807 non-null  float64
#  5   V6      284807 non-null  float64
#  6   V7      284807 non-null  float64
#  7   V8      284807 non-null  float64
#  8   V9      284807 non-null  float64
#  9   V10     284807 non-null  float64
#  10  V11     284807 non-null  float64
#  11  V12     284807 non-null  float64
#  12  V13     284807 non-null  float64
#  13  V14     284807 non-null  float64
#  14  V15     284807 non-null  float64
#  15  V16     284807 non-null  float64
#  16  V17     284807 non-null  float64
#  17  V18     284807 non-null  float64
#  18  V19     284807 non-null  float64
#  19  V20     284807 non-null  float64
# ...

# %% [markdown]
# split data into traing and test

# %%
from sklearn.model_selection import train_test_split

# %%
x=creditcard.drop('Class',axis=1)
y=creditcard['Class']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 132606 -1.758034  1.064656  1.539083 -0.132717 -1.132644 -0.294953 -0.240062
# 193000  2.029529  0.167341 -1.927112  1.229096  0.824194 -0.689953  0.705856
# 60630   0.282179  1.051097  0.846770  1.393560  0.217295 -0.321159  0.580914
# 30539  -1.561114 -0.056598  0.965534 -0.980123 -1.847782  1.169454  1.918609
# 150920 -0.026415 -0.157115 -0.787080 -2.764438  2.408881  3.455078 -0.767630
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 132606  0.707134  0.514097 -0.692270  ... -0.546878  0.285996  0.758855
# 193000 -0.412589  0.158755  0.228566  ... -0.182210  0.023573  0.269365
# 60630  -0.190127 -0.655909  0.152240  ...  0.160109  0.129850  0.561569
# 30539   0.177554 -0.324433 -1.001388  ... -0.067507  0.019671  0.053102
# 150920  0.974856  0.512396 -1.169027  ...  0.085009  0.121223  0.413201
#
# ...

# %% [markdown]
# Scaling the amount column

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train['Amount']=scaler.fit_transform(x_train[['Amount']])

# %%
x_train.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 132606 -1.758034  1.064656  1.539083 -0.132717 -1.132644 -0.294953 -0.240062
# 193000  2.029529  0.167341 -1.927112  1.229096  0.824194 -0.689953  0.705856
# 60630   0.282179  1.051097  0.846770  1.393560  0.217295 -0.321159  0.580914
# 30539  -1.561114 -0.056598  0.965534 -0.980123 -1.847782  1.169454  1.918609
# 150920 -0.026415 -0.157115 -0.787080 -2.764438  2.408881  3.455078 -0.767630
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 132606  0.707134  0.514097 -0.692270  ... -0.546878  0.285996  0.758855
# 193000 -0.412589  0.158755  0.228566  ... -0.182210  0.023573  0.269365
# 60630  -0.190127 -0.655909  0.152240  ...  0.160109  0.129850  0.561569
# 30539   0.177554 -0.324433 -1.001388  ... -0.067507  0.019671  0.053102
# 150920  0.974856  0.512396 -1.169027  ...  0.085009  0.121223  0.413201
#
# ...

# %%
x_test['Amount']=scaler.fit_transform(x_test[['Amount']])

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=0.1)
lasso.fit(x_train,y_train)

feature_importance = pd.Series(lasso.coef_, index=x.columns)
feature_importance = feature_importance.sort_values(ascending=False)
print(feature_importance)
# Out:
# V1       -0.0
# V16      -0.0
# V28       0.0
# V27       0.0
# V26       0.0
# V25       0.0
# V24      -0.0
# V23      -0.0
# V22       0.0
# V21       0.0
# V20       0.0
# V19       0.0
# V18      -0.0
# V17      -0.0
# V15      -0.0
# V2        0.0
# V14      -0.0
# V13      -0.0
# V12      -0.0
# V11       0.0
# V10      -0.0
# V9       -0.0
# V8        0.0
# V7       -0.0
# V6       -0.0
# V5       -0.0
# V4        0.0
# V3       -0.0
# Amount    0.0
# dtype: float64

# %% [markdown]
# # Plotting the distribution of the variables (skewness) of all the columns

# %%
cols=x_train.columns
cols
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 cols=x_train.columns
#       2 cols
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
k=0
plt.figure(figsize=(17,28))
for col in cols:
    k=k+1
    plt.subplot(6,5,k)
    sns.distplot(x_train[col])
    plt.title(col+' '+str(x_train[col].skew()))

# %% [markdown]
# we can see that the features are heavily skewed hence we need to transform data into normal distribution

# %%
from sklearn.preprocessing import PowerTransformer

# %%
transform=PowerTransformer(method='yeo-johnson',standardize=True,copy=False)
x_train[cols]=transform.fit_transform(x_train)

# %%
# Transform the test set
x_test[cols] = transform.transform(x_test)

# %% [markdown]
# # After Transformation, check skewness

# %%
k=0
plt.figure(figsize=(17,28))
for col in cols:
    k=k+1
    plt.subplot(6,5,k)
    sns.distplot(x_train[col])
    plt.title(col+' '+str(x_train[col].skew()))

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
model=lr.fit(x_train,y_train)
lr_scrore=model.score(x_test,y_test)
print("Logistic Regression model score: "+str(lr_scrore*100)+"%")
# Out:
# Logistic Regression model score: 99.91372608030497%

# %% [markdown]
# Since the data is imbalanced hence we are getting a good score

# %%
from sklearn.metrics import confusion_matrix
ypreds=lr.predict(x_test)

# %%
print(classification_report(y_test,ypreds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    199007
#            1       0.87      0.61      0.72       358
#
#     accuracy                           1.00    199365
#    macro avg       0.94      0.80      0.86    199365
# weighted avg       1.00      1.00      1.00    199365

# %%
pd.crosstab(y_test,ypreds,rownames=["actual values"],colnames=["predicted values"])
# Out:
# predicted values       0    1
# actual values
# 0                 198975   32
# 1                    140  218

# %%
from sklearn.metrics import classification_report
ytrain_pred=lr.predict(x_train)
print(classification_report(y_train,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85308
#            1       0.89      0.66      0.76       134
#
#     accuracy                           1.00     85442
#    macro avg       0.94      0.83      0.88     85442
# weighted avg       1.00      1.00      1.00     85442

# %%
creditcard["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# #### hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
folds=KFold(n_splits=5,shuffle=True,random_state=4)
params={"C":[0.01,0.1,10,150,300,500,800,1000]}
model_gridsearch=GridSearchCV(estimator=LogisticRegression(),
                             param_grid=params,
                             cv=folds,
                             verbose=1,
                             n_jobs=-1,
                             return_train_score=True)

model_gridsearch.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=4, shuffle=True),
#              estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 10, 150, 300, 500, 800, 1000]},
#              return_train_score=True, verbose=1)

# %%
bestparam=model_gridsearch.best_params_
print("Best Params: "+ str(bestparam))
# Out:
# Best Params: {'C': 0.1}

# %%
#instantiate model with best param
new_lr_model=LogisticRegression(C=0.1)
new_lr_model.fit(x_train,y_train)
# Out:
# LogisticRegression(C=0.1)

# %%
new_lr_model_score=new_lr_model.score(x_test,y_test)
print("new Logistic Regression model score: "+str(new_lr_model_score*100)+"%")
# Out:
# new Logistic Regression model score: 99.91071652496677%

# %%
#classification report on train data using new model
ytrain_pred_new=new_lr_model.predict(x_train)
print(classification_report(y_train,ytrain_pred_new))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85308
#            1       0.89      0.66      0.76       134
#
#     accuracy                           1.00     85442
#    macro avg       0.94      0.83      0.88     85442
# weighted avg       1.00      1.00      1.00     85442

# %%
#classification report on test data using new model
ytest_pred_new=new_lr_model.predict(x_test)
print(classification_report(y_test,ytest_pred_new))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    199007
#            1       0.87      0.59      0.70       358
#
#     accuracy                           1.00    199365
#    macro avg       0.93      0.80      0.85    199365
# weighted avg       1.00      1.00      1.00    199365

# %%
cross_val=cross_val_score(new_lr_model,x,y,cv=folds,n_jobs=-1)
print(cross_val)
# Out:
# /Users/suryanshmamgain/Desktop/ml-course/heart-disease-project/env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/suryanshmamgain/Desktop/ml-course/heart-disease-project/env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
confusion = confusion_matrix(y_test, ytest_pred_new)
print(confusion)
# Out:
# [[198975     32]
#  [   146    212]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
from sklearn.metrics import accuracy_score,f1_score
# Accuracy
print("Accuracy:-",accuracy_score(y_test, ytest_pred_new))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(y_test, ytest_pred_new))
# Out:
# Accuracy:- 0.9991071652496677
# Sensitivity:- 0.5921787709497207
# Specificity:- 0.9998392016361234
# F1-Score:- 0.7043189368770764

# %%
#plot the ROC Curve
ytest_pred_prob=new_lr_model.predict_proba(x_test)[:,1]
print(ytest_pred_prob)
# Out:
# [2.01022110e-05 3.76212112e-04 1.25854848e-04 ... 4.75981047e-05
#  2.66590442e-04 9.64370289e-05]

# %%
# ROC Curve function

def draw_roc( actual, probs ):
    fpr, tpr, thresholds = metrics.roc_curve( actual, probs,
                                              drop_intermediate = False )
    auc_score = metrics.roc_auc_score( actual, probs )
    plt.figure(figsize=(5, 5))
    plt.plot( fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score )
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

    return None

# %%
from sklearn import metrics

# %%
draw_roc(y_test,ytest_pred_prob)

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decision_model=DecisionTreeClassifier();
decision_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
decision_model.score(x_test,y_test)
# Out:
# 0.9989817671105761

# %%
#check training classification report
decision_ytrainpreds=decision_model.predict(x_train)
print(classification_report(y_train,decision_ytrainpreds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85308
#            1       1.00      1.00      1.00       134
#
#     accuracy                           1.00     85442
#    macro avg       1.00      1.00      1.00     85442
# weighted avg       1.00      1.00      1.00     85442

# %%
#check test calssification report
decision_ytestpreds=decision_model.predict(x_test)
print(classification_report(y_test,decision_ytestpreds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    199007
#            1       0.71      0.73      0.72       358
#
#     accuracy                           1.00    199365
#    macro avg       0.85      0.87      0.86    199365
# weighted avg       1.00      1.00      1.00    199365

# %% [markdown]
# #### hypertuning

# %%
folds=3
params={'max_depth': range(5, 15, 3),
    'min_samples_leaf': range(10, 100, 10),
    'min_samples_split': range(10, 100, 10),
}
decision_gridmodel=GridSearchCV(estimator=DecisionTreeClassifier(),
                               param_grid=params,
                               cv=folds,
                               n_jobs=-1,
                               )
decision_gridmodel.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': range(5, 15, 3),
#                          'min_samples_leaf': range(10, 100, 10),
#                          'min_samples_split': range(10, 100, 10)})

# %%
print("Best Params: "+str(decision_gridmodel.best_params_))
print("Best Esitimator: "+str(decision_gridmodel.best_estimator_))
# Out:
# Best Params: {'max_depth': 5, 'min_samples_leaf': 20, 'min_samples_split': 90}
# Best Esitimator: DecisionTreeClassifier(max_depth=5, min_samples_leaf=20, min_samples_split=90)

# %%
decision_gridmodel_new=DecisionTreeClassifier(max_depth=5,min_samples_leaf=20,min_samples_split=90)
decision_gridmodel_new.fit(x_train,y_train)
decision_gridmodel_new.score(x_test,y_test)
# Out:
# 0.9990018308128308

# %%
#plot ROC curve
decision_ytestpreds_new=decision_gridmodel_new.predict_proba(x_test)[:,1]
draw_roc(y_test,decision_ytestpreds_new)

# %% [markdown]
# ### RandomForest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rand=RandomForestClassifier()
rand.fit(x_train,y_train)
rand.score(x_test,y_test)
# Out:
# 0.9993629774534146

# %% [markdown]
# #### hyperparameter tuning

# %%
params={
    'n_estimators': [200],
    'max_depth': range(1,15,3),
    'min_samples_split': range(10, 100, 10),
    'min_samples_leaf': range(10,100,10) 
}
rand_gridmodel=GridSearchCV(estimator=RandomForestClassifier(),
                           param_grid=params,
                           verbose=1,
                           n_jobs=-1,
                           cv=5,
                           return_train_score=True)
rand_gridmodel.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 405 candidates, totalling 2025 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[119], line 13
#       1 params={
#       2     'n_estimators': [200],
#       3     'max_depth': range(1,15,3),
#       4     'min_samples_split': range(10, 100, 10),
#       5     'min_samples_leaf': range(10,100,10)
#       6 }
#       7 rand_gridmodel=GridSearchCV(estimator=RandomForestClassifier(),
#       8                            param_grid=params,
#       9                            verbose=1,
#      10                            n_jobs=-1,
#      11                            cv=5,
#      12                            return_train_score=True)
# ---> 13 rand_gridmodel.fit(x_train,y_train)
#
# ...

# %% [markdown]
# ### since the data is imbalance hence we need to resample the data..
# 1. Undersampling
# 2. Oversampling

# %%
pip install imbalanced-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 393.7 kB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
##oversampling
from imblearn.over_sampling import RandomOverSampler

# %%
ros=RandomOverSampler()
xtrain_ros,ytrain_ros=ros.fit_resample(x_train,y_train)

# %%
from collections import Counter
print("Before: ",Counter(y_train))
print("After: ",Counter(ytrain_ros))
print(Counter(y_test))
# Out:
# Before:  Counter({0: 199017, 1: 347})
# After:  Counter({0: 199017, 1: 199017})
# Counter({0: 85298, 1: 145})

# %%
## repeat the same steps as above
